# %%
from random import randint
edades = []
cont = 0
ran = randint (13,43)
while cont < 20:
    ran = randint (13,43)
    if ran in edades:
        pass
    else:
        edades.append(ran)
        cont = cont + 1
if not 16 in edades:
    edades[3] = 16

def ordenar (edades):
    for i in range (int(len(edades))-1):
        val = edades[i]
        men = edades[i]
        IndexMenor = i
        for j in range (i,len(edades)):
            if edades[j] < men:
                men = edades[j]
                IndexMenor = j
        edades[i] = men
        edades[IndexMenor] = val
    return edades

def buscar(edades, busca):
    mitad = int(len(edades)/2)
    i = edades[mitad]
    print(i)
    while i != busca:
        if i > busca:
            mitad = mitad -1
        else:
            mitad = mitad + 1
        i = edades[mitad]
    return mitad

orden=ordenar(edades)
buscando= buscar(edades, 16)

print(edades)
print (buscando)
# Out:
# 31
# [13, 16, 17, 18, 20, 24, 25, 26, 27, 29, 31, 32, 33, 34, 35, 38, 39, 40, 42, 43]
# 1
